# %%
import matplotlib.pyplot as plt
import seaborn as sns

total = 542
unique_percentage = (13/542) * 100

# Calculate the number of unique items
unique_count = total * unique_percentage / 100

# Calculate the number of non-unique items
non_unique_count = total - unique_count

# Create the pie chart
labels = ['Failures in low battery level', '']
counts = [unique_count, non_unique_count]
colors = ['red', 'purple']

plt.pie(counts, labels=labels, autopct='%1.1f%%')

# Add a title
plt.title('Failures that occured in Low Voltage Level')

# Display the pie chart
plt.show()

# %%
sns.set_palette('deep')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


total = 542
unique_percentage = (181/542) * 100

# Calculate the number of unique items
unique_count = total * unique_percentage / 100

# Calculate the number of non-unique items
non_unique_count = total - unique_count

# Create lists of counts and corresponding labels
counts = [unique_count, non_unique_count]
labels = ['No swtich good RSSI', 'Others']

# Plot the pie chart
sns.set()
plt.pie(counts, labels=labels, autopct='%1.1f%%')

# Add a title
plt.title('No gateway switch after failure and good RSSI before and after failure (180 failures) ')

# Display the pie chart
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


total = 542
unique_percentage = (390/542) * 100

# Calculate the number of unique items
unique_count = total * unique_percentage / 100

# Calculate the number of non-unique items
non_unique_count = total - unique_count

# Create lists of counts and corresponding labels
counts = [unique_count, non_unique_count]
labels = ['No gateway swtich', 'Gateway Switch']

# Plot the pie chart
sns.set()
plt.pie(counts, labels=labels, autopct='%1.1f%%')

# Add a title
plt.title('No gateway switch after failure (390 failures)')

# Display the pie chart
plt.show()
