# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sensor_data_file = "/Users/ashoktimsina/Desktop/Floodnet2/Distance Experiment 4-1(opposite).xlsx"
df = pd.read_excel(sensor_data_file)
df
# Out:
#     Ground Truth   Laser  Maxbotix Mean  Std Deviantion  Variance  Error  \
# 0         3100.0  3101.0        3108.13        0.485237  0.235455   8.13
# 1         3000.0  3000.0        3007.81        0.646592  0.418081   7.81
# 2         2900.0  2901.0        2906.50        0.643538  0.414141   6.50
# 3         2800.0  2800.0        2806.76        0.514831  0.265051   6.76
# 4         2700.0  2701.0        2707.62        0.487832  0.237980   7.62
# ..           ...     ...            ...             ...       ...    ...
# 95           NaN     NaN            NaN             NaN       NaN    NaN
# 96           NaN     NaN            NaN             NaN       NaN    NaN
# 97           NaN     NaN            NaN             NaN       NaN    NaN
# 98           NaN     NaN            NaN             NaN       NaN    NaN
# 99           NaN     NaN            NaN             NaN       NaN    NaN
#
#     Percentage Error  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 20  \
# ...

# %%
reading_cols = df.columns[9:30]
distance_data = df[reading_cols]
distance_data
# Out:
#     Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         3108         3009         2907         2806         2708
# 1         3107         3009         2906         2806         2708
# 2         3108         3009         2907         2806         2708
# 3         3108         3008         2907         2807         2708
# 4         3108         3009         2907         2806         2708
# ..         ...          ...          ...          ...          ...
# 95        3108         3007         2907         2807         2708
# 96        3108         3008         2907         2807         2708
# 97        3108         3008         2907         2807         2708
# 98        3108         3008         2908         2807         2708
# 99        3108         3008         2907         2808         2708
#
#     Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  ...  \
# 0          2608         2505         2400         2307         2207  ...
# ...

# %%
ground_truth = 3100
for col in reading_cols:
    error_col_name = col + 'error'
    distance_data[error_col_name] = distance_data[col] - ground_truth
    ground_truth -= 100
# Out:
# /var/folders/w8/hf1h4sln0w59j24yg9xg14bw0000gn/T/ipykernel_19348/1418822904.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   distance_data[error_col_name] = distance_data[col] - ground_truth
# /var/folders/w8/hf1h4sln0w59j24yg9xg14bw0000gn/T/ipykernel_19348/1418822904.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   distance_data[error_col_name] = distance_data[col] - ground_truth
# ...

# %%
distance_data
# Out:
#     Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         3108         3009         2907         2806         2708
# 1         3107         3009         2906         2806         2708
# 2         3108         3009         2907         2806         2708
# 3         3108         3008         2907         2807         2708
# 4         3108         3009         2907         2806         2708
# ..         ...          ...          ...          ...          ...
# 95        3108         3007         2907         2807         2708
# 96        3108         3008         2907         2807         2708
# 97        3108         3008         2907         2807         2708
# 98        3108         3008         2908         2807         2708
# 99        3108         3008         2907         2808         2708
#
#     Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  ...  \
# 0          2608         2505         2400         2307         2207  ...
# ...

# %%
error_dat = distance_data.columns[21:42]
# fig, axs = plt.subplots(10,10)
# #fig.suptitle('Vertically stacked subplots')

# for i in range(9):
#     for j in range(9):
#         for cols in error_dat[:-2]:
#             axs[i,j].hist(cols)
#             i += 1
distance_data[error_dat]
# Out:
#     Unnamed: 9error  Unnamed: 10error  Unnamed: 11error  Unnamed: 12error  \
# 0                 8                 9                 7                 6
# 1                 7                 9                 6                 6
# 2                 8                 9                 7                 6
# 3                 8                 8                 7                 7
# 4                 8                 9                 7                 6
# ..              ...               ...               ...               ...
# 95                8                 7                 7                 7
# 96                8                 8                 7                 7
# 97                8                 8                 7                 7
# 98                8                 8                 8                 7
# 99                8                 8                 7                 8
#
#     Unnamed: 13error  Unnamed: 14error  Unnamed: 15error  Unnamed: 16error  \
# ...

# %%
distance_data[error_dat].hist(bins=5, figsize=(20, 20))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 9error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 10error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 11error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 12error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 13error'}>],
#        [<AxesSubplot:title={'center':'Unnamed: 14error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 15error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 16error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 17error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 18error'}>],
#        [<AxesSubplot:title={'center':'Unnamed: 19error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 20error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 21error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 22error'}>,
#         <AxesSubplot:title={'center':'Unnamed: 23error'}>],
#        [<AxesSubplot:title={'center':'Unnamed: 24error'}>,
# ...

# %%
x = df["Ground Truth"]
y = df["Error"]
plt.scatter(x,y)
