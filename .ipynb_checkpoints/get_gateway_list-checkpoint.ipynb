# %%
import requests
import pandas as pd

# %%
# API endpoint URL
url = "https://eu1.cloud.thethings.network/api/v3/gateways?page=1&limit=20&order=-created_at&field_mask=name,description,frequency_plan_ids,gateway_server_address"

# API key for authentication
api_key = "NNSXS.WZ4B7FZGDLKCM6XJEQB6DMNAOQYJL7ODMYY6ELA.CR6ACJD3Q2OV3NMCZTSOSR4T5YGH6PDCA7IDJGEGNZ3Q3OY5EWTQ"

# Request headers
headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"

}

# %%
try:
    # Send GET request to the API endpoint
    response = requests.get(url, headers=headers)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Access the response data
        data = response.json()

        # Process the data as needed
        gateway_list = data["gateways"]

        # Convert the list of dictionaries to a DataFrame
        df = pd.DataFrame(gateway_list)

        # Specify the desired columns
        columns = ['ids', "name", "gateway_server_address", "description", "frequency_plan_ids"]

        # Subset the DataFrame with the desired columns
        df_subset = df[columns]

    else:
        print(f"Request failed with status code {response.status_code}")
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")

# %%
df_subset
# Out:
#                                                   ids  \
# 0   {'gateway_id': 'floodnet-ltap-gw-553232200e001...
# 1   {'gateway_id': 'floodnet-ltap-gw-553232201d004...
# 2   {'gateway_id': 'floodnet-ltap-gw-553232201d003...
# 3   {'gateway_id': 'gateway-drexel1', 'eui': '3235...
# 4   {'gateway_id': 'fngw-10006', 'eui': '343632381...
# 5   {'gateway_id': 'floodnet-ltap-gw-553232201e001...
# 6   {'gateway_id': 'floodnet-ltap-gw-5532322031005...
# 7   {'gateway_id': 'floodnet-lr9-gw-32353132290069...
# 8   {'gateway_id': 'fngw-10003', 'eui': '343632381...
# 9   {'gateway_id': 'floodnet-ltap-gw-313330372b002...
# 10  {'gateway_id': 'floodnet-ltap-gw-313330372b007...
# 11  {'gateway_id': 'fngw-10001', 'eui': '343632383...
# 12  {'gateway_id': 'kona-mega', 'eui': '647FDAFFFE...
# 13  {'gateway_id': 'floodnet-ltap-gw-3235313237006...
# 14  {'gateway_id': 'fngw-10000', 'eui': '343632384...
# 15  {'gateway_id': 'ttn-nyc-00-08-00-4a-6c-58', 'e...
# 16  {'gateway_id': 'ngens-01-v3', 'eui': '34363238...
# 17  {'gateway_id': 'nyc-mocto-1', 'eui': '32353132...
#
#                                              name  \
# 0                          FloodNet ltap - PS181Q
# 1          floodnet ltap for Ocean Breeze - SI #2
# 2                      FloodNet/NYC Mesh - Vernon
# 3                                             NaN
# 4                           floodnet at PRHS - SI
# 5                   FloodNet South Jamaica Houses
# 6             floodnet ltap for Ocean Breeze - SI
# 7                            FloodNet Gowanus LR9
# 8                    floodnet at CSI R1 bldg - SI
# 9                      FloodNet Bronx River House
# 10  FloodNet/Voltaic Navy Yard (313330372b007400)
# 11                          CUNY ASRC Observatory
# 12                             Tektelic Kona Mega
# 13                FloodNet Pioneer Works Red Hook
# 14                     floodnet in Hamilton Beach
# 15        thethings.nyc #6 (CUSP NYU 370 Jay St.)
# 16                      floodnet at RISE Rockaway
# 17                                       PS189-BK
#
#           gateway_server_address  \
# 0   nam1.cloud.thethings.network
# 1   nam1.cloud.thethings.network
# 2   nam1.cloud.thethings.network
# 3   nam1.cloud.thethings.network
# 4   nam1.cloud.thethings.network
# 5   nam1.cloud.thethings.network
# 6   nam1.cloud.thethings.network
# 7   nam1.cloud.thethings.network
# 8   nam1.cloud.thethings.network
# 9   nam1.cloud.thethings.network
# 10  nam1.cloud.thethings.network
# 11  nam1.cloud.thethings.network
# 12  nam1.cloud.thethings.network
# 13  nam1.cloud.thethings.network
# 14  nam1.cloud.thethings.network
# 15  nam1.cloud.thethings.network
# 16  nam1.cloud.thethings.network
# 17  nam1.cloud.thethings.network
#
#                                           description  frequency_plan_ids
# 0                         SIM ID: 8901260882286249401  [US_902_928_FSB_2]
# 1   vpn4.remotewinbox.com:16147\nIMEI:861641041237...  [US_902_928_FSB_2]
# 2                         SIM ID: 8901260882280552701  [US_902_928_FSB_2]
# 3                                                 NaN  [US_902_928_FSB_2]
# 4                       vpn3.remotewinbox.com:36641\n  [US_902_928_FSB_2]
# 5                         SIM ID: 8901260882280553865  [US_902_928_FSB_2]
# 6   in lab\nvpn3.remotewinbox.com:47482\nIMEI: 861...  [US_902_928_FSB_2]
# 7                                FloodNet Gowanus LR9  [US_902_928_FSB_2]
# 8   College of Staten Island, CUNY, rec bldg rooft...  [US_902_928_FSB_2]
# 9                                                 NaN  [US_902_928_FSB_2]
# 10  WiFi AP: floodnet-ltap-ap\nOff grid power setu...  [US_902_928_FSB_2]
# 11  CUNY ASRC Observatory\nwifi e34%GH!@9L\nvpn3.r...  [US_902_928_FSB_2]
# 12                                                NaN  [US_902_928_FSB_2]
# 13  WiFi AP: floodnet-ltap-ap\nPW 2G IP: 192.168.8...  [US_902_928_FSB_2]
# 14  mikrotik lora9 on roof of WHBVFD firehouse \no...  [US_902_928_FSB_2]
# 15                                                NaN  [US_902_928_FSB_2]
# 16  Setup 6.23.2021 by Ilir and Alban.\nwifi N63n5...  [US_902_928_FSB_2]
# 17        NYC MOCTO Central Brooklyn Gateway at PS189  [US_902_928_FSB_2]

# %%
df_subset.loc[:,'gateway_id'] = gateway_ids = [ids['gateway_id'] for ids in df_subset['ids']]
df_subset.loc[:,'eui'] = gateway_ids = [ids['eui'] for ids in df_subset['ids']]
# Out:
# /Users/ashoktimsina/Desktop/Floodnet2/floodnet/lib/python3.7/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/ashoktimsina/Desktop/Floodnet2/floodnet/lib/python3.7/site-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
df_subset.drop(['ids'], inplace=True, axis=1)
# Out:
# /Users/ashoktimsina/Desktop/Floodnet2/floodnet/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_subset
# Out:
#                                              name  \
# 0                          FloodNet ltap - PS181Q
# 1          floodnet ltap for Ocean Breeze - SI #2
# 2                      FloodNet/NYC Mesh - Vernon
# 3                                             NaN
# 4                           floodnet at PRHS - SI
# 5                   FloodNet South Jamaica Houses
# 6             floodnet ltap for Ocean Breeze - SI
# 7                            FloodNet Gowanus LR9
# 8                    floodnet at CSI R1 bldg - SI
# 9                      FloodNet Bronx River House
# 10  FloodNet/Voltaic Navy Yard (313330372b007400)
# 11                          CUNY ASRC Observatory
# 12                             Tektelic Kona Mega
# 13                FloodNet Pioneer Works Red Hook
# 14                     floodnet in Hamilton Beach
# 15        thethings.nyc #6 (CUSP NYU 370 Jay St.)
# 16                      floodnet at RISE Rockaway
# 17                                       PS189-BK
#
#           gateway_server_address  \
# 0   nam1.cloud.thethings.network
# 1   nam1.cloud.thethings.network
# 2   nam1.cloud.thethings.network
# 3   nam1.cloud.thethings.network
# 4   nam1.cloud.thethings.network
# 5   nam1.cloud.thethings.network
# 6   nam1.cloud.thethings.network
# 7   nam1.cloud.thethings.network
# 8   nam1.cloud.thethings.network
# 9   nam1.cloud.thethings.network
# 10  nam1.cloud.thethings.network
# 11  nam1.cloud.thethings.network
# 12  nam1.cloud.thethings.network
# 13  nam1.cloud.thethings.network
# 14  nam1.cloud.thethings.network
# 15  nam1.cloud.thethings.network
# 16  nam1.cloud.thethings.network
# 17  nam1.cloud.thethings.network
#
#                                           description  frequency_plan_ids  \
# 0                         SIM ID: 8901260882286249401  [US_902_928_FSB_2]
# 1   vpn4.remotewinbox.com:16147\nIMEI:861641041237...  [US_902_928_FSB_2]
# 2                         SIM ID: 8901260882280552701  [US_902_928_FSB_2]
# 3                                                 NaN  [US_902_928_FSB_2]
# 4                       vpn3.remotewinbox.com:36641\n  [US_902_928_FSB_2]
# 5                         SIM ID: 8901260882280553865  [US_902_928_FSB_2]
# 6   in lab\nvpn3.remotewinbox.com:47482\nIMEI: 861...  [US_902_928_FSB_2]
# 7                                FloodNet Gowanus LR9  [US_902_928_FSB_2]
# 8   College of Staten Island, CUNY, rec bldg rooft...  [US_902_928_FSB_2]
# 9                                                 NaN  [US_902_928_FSB_2]
# 10  WiFi AP: floodnet-ltap-ap\nOff grid power setu...  [US_902_928_FSB_2]
# 11  CUNY ASRC Observatory\nwifi e34%GH!@9L\nvpn3.r...  [US_902_928_FSB_2]
# 12                                                NaN  [US_902_928_FSB_2]
# 13  WiFi AP: floodnet-ltap-ap\nPW 2G IP: 192.168.8...  [US_902_928_FSB_2]
# 14  mikrotik lora9 on roof of WHBVFD firehouse \no...  [US_902_928_FSB_2]
# 15                                                NaN  [US_902_928_FSB_2]
# 16  Setup 6.23.2021 by Ilir and Alban.\nwifi N63n5...  [US_902_928_FSB_2]
# 17        NYC MOCTO Central Brooklyn Gateway at PS189  [US_902_928_FSB_2]
#
#                            gateway_id               eui
# 0   floodnet-ltap-gw-553232200e001300  553232200E001300
# 1   floodnet-ltap-gw-553232201d004100  553232201D004100
# 2   floodnet-ltap-gw-553232201d003500  553232201D003500
# 3                     gateway-drexel1  3235313249002900
# 4                          fngw-10006  343632381F006B00
# 5   floodnet-ltap-gw-553232201e001500  553232201E001500
# 6   floodnet-ltap-gw-5532322031005e00  5532322031005E00
# 7    floodnet-lr9-gw-3235313229006900  3235313229006900
# 8                          fngw-10003  343632381E005B00
# 9   floodnet-ltap-gw-313330372b002900  313330372B002900
# 10  floodnet-ltap-gw-313330372b007400  313330372B007400
# 11                         fngw-10001  343632383C006E00
# 12                          kona-mega  647FDAFFFE005BD6
# 13  floodnet-ltap-gw-3235313237006e00  3235313237006E00
# 14                         fngw-10000  343632384A004000
# 15          ttn-nyc-00-08-00-4a-6c-58  00800000A00036B8
# 16                        ngens-01-v3  343632383E003000
# 17                        nyc-mocto-1  3235313213004700

# %%
df_subset.columns
# Out:
# Index(['name', 'gateway_server_address', 'description', 'frequency_plan_ids',
#        'gateway_id', 'eui'],
#       dtype='object')

# %%
column_order = ['gateway_id', 'eui', 'name', 'gateway_server_address', 'description', 'frequency_plan_ids']
final_df = df_subset.reindex(columns=column_order)

# %%
final_df.to_csv("gateway_list.csv")
