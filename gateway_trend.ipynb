# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %store -r

# %%
sns.set(rc = {'figure.figsize':(12,3)})
# %config InlineBackend.figure_format = 'retina'

# %%
intrested_sensors = ['daily_new_falcon']

# %%
for sensor in intrested_sensors:
    df = dataframes_100[sensor][137000:]
    
    sns.scatterplot(x = 'time', y = 'sf', data = df, hue = 'gw_1_id', s = 1)

# %%
df.shape
# Out:
# (477, 45)

# %%
df
# Out:
#         Unnamed: 0                              time   measurement  \
# 137000      137000  2023-07-18 07:12:47.084000+00:00  flood-sensor
# 137001      137001  2023-07-18 07:13:50.513000+00:00  flood-sensor
# 137002      137002  2023-07-18 07:14:53.655000+00:00  flood-sensor
# 137003      137003  2023-07-18 07:15:56.882000+00:00  flood-sensor
# 137004      137004  2023-07-18 07:17:00.154000+00:00  flood-sensor
# ...            ...                               ...           ...
# 137472      137472  2023-07-18 15:26:36.112000+00:00  flood-sensor
# 137473      137473  2023-07-18 15:27:39.436000+00:00  flood-sensor
# 137474      137474  2023-07-18 15:28:42.864000+00:00  flood-sensor
# 137475      137475  2023-07-18 15:28:50.680000+00:00  flood-sensor
# 137476      137476  2023-07-18 15:29:54.128000+00:00  flood-sensor
#
#              app_name   bw_hz coding_rate     deployment_id  dev_addr  \
# 137000  floodnet-live  125000         4/5  daily_new_falcon  260C8EB9
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'time', 'measurement', 'app_name', 'bw_hz', 'coding_rate',
#        'deployment_id', 'dev_addr', 'dev_eui', 'dev_id', 'error_flag',
#        'f_port', 'gw_1_id', 'network', 'sf', 'airtime_s', 'batt_v',
#        'depth_filt_mm', 'depth_proc_dist_mm', 'depth_proc_mm', 'depth_raw_mm',
#        'dist_mm', 'f_cnt', 'flood_detected', 'gw_1_rssi_dbm', 'gw_1_snr_db',
#        'lora_freq_hz', 'gw_2_id', 'gw_2_rssi_dbm', 'gw_2_snr_db', 'gw_3_id',
#        'gw_3_rssi_dbm', 'gw_3_snr_db', 'gw_4_id', 'gw_4_rssi_dbm',
#        'gw_4_snr_db', 'gw_5_id', 'gw_5_rssi_dbm', 'gw_5_snr_db', 'gw_6_id',
#        'gw_6_rssi_dbm', 'gw_6_snr_db', 'depth_filt_stages_applied', 'times',
#        'date'],
#       dtype='object')

# %%
df['sf']
# Out:
# 137000    7
# 137001    7
# 137002    7
# 137003    7
# 137004    7
#          ..
# 137472    7
# 137473    7
# 137474    7
# 137475    7
# 137476    7
# Name: sf, Length: 477, dtype: int64
